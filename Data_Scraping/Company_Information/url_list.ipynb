# %%
import pandas as pd

# %%
#'https://finance.yahoo.com/quote/AAPL?p=AAPL'

# %%
df = pd.read_csv('/Data/company_info.csv' , usecols=['Ticker'])

# %%
ticker_list = list(df['Ticker'])
ticker_list
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISH',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DD',
#  'DXC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'RE',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GEHC',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OGN',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PKI',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'VICI',
#  'V',
#  'VMC',
#  'WAB',
#  'WBA',
#  'WMT',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'GWW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
url_list = []

for i  in ticker_list:
    url_list.append(f'https://finance.yahoo.com/quote/{i}?p={i}')

# %%
url_list
# Out:
# ['https://finance.yahoo.com/quote/MMM?p=MMM',
#  'https://finance.yahoo.com/quote/AOS?p=AOS',
#  'https://finance.yahoo.com/quote/ABT?p=ABT',
#  'https://finance.yahoo.com/quote/ABBV?p=ABBV',
#  'https://finance.yahoo.com/quote/ACN?p=ACN',
#  'https://finance.yahoo.com/quote/ATVI?p=ATVI',
#  'https://finance.yahoo.com/quote/ADM?p=ADM',
#  'https://finance.yahoo.com/quote/ADBE?p=ADBE',
#  'https://finance.yahoo.com/quote/ADP?p=ADP',
#  'https://finance.yahoo.com/quote/AAP?p=AAP',
#  'https://finance.yahoo.com/quote/AES?p=AES',
#  'https://finance.yahoo.com/quote/AFL?p=AFL',
#  'https://finance.yahoo.com/quote/A?p=A',
#  'https://finance.yahoo.com/quote/APD?p=APD',
#  'https://finance.yahoo.com/quote/AKAM?p=AKAM',
#  'https://finance.yahoo.com/quote/ALK?p=ALK',
#  'https://finance.yahoo.com/quote/ALB?p=ALB',
#  'https://finance.yahoo.com/quote/ARE?p=ARE',
#  'https://finance.yahoo.com/quote/ALGN?p=ALGN',
#  'https://finance.yahoo.com/quote/ALLE?p=ALLE',
#  'https://finance.yahoo.com/quote/LNT?p=LNT',
#  'https://finance.yahoo.com/quote/ALL?p=ALL',
#  'https://finance.yahoo.com/quote/GOOGL?p=GOOGL',
#  'https://finance.yahoo.com/quote/GOOG?p=GOOG',
#  'https://finance.yahoo.com/quote/MO?p=MO',
#  'https://finance.yahoo.com/quote/AMZN?p=AMZN',
#  'https://finance.yahoo.com/quote/AMCR?p=AMCR',
#  'https://finance.yahoo.com/quote/AMD?p=AMD',
#  'https://finance.yahoo.com/quote/AEE?p=AEE',
#  'https://finance.yahoo.com/quote/AAL?p=AAL',
#  'https://finance.yahoo.com/quote/AEP?p=AEP',
#  'https://finance.yahoo.com/quote/AXP?p=AXP',
#  'https://finance.yahoo.com/quote/AIG?p=AIG',
#  'https://finance.yahoo.com/quote/AMT?p=AMT',
#  'https://finance.yahoo.com/quote/AWK?p=AWK',
#  'https://finance.yahoo.com/quote/AMP?p=AMP',
#  'https://finance.yahoo.com/quote/ABC?p=ABC',
#  'https://finance.yahoo.com/quote/AME?p=AME',
#  'https://finance.yahoo.com/quote/AMGN?p=AMGN',
#  'https://finance.yahoo.com/quote/APH?p=APH',
#  'https://finance.yahoo.com/quote/ADI?p=ADI',
#  'https://finance.yahoo.com/quote/ANSS?p=ANSS',
#  'https://finance.yahoo.com/quote/AON?p=AON',
#  'https://finance.yahoo.com/quote/APA?p=APA',
#  'https://finance.yahoo.com/quote/AAPL?p=AAPL',
#  'https://finance.yahoo.com/quote/AMAT?p=AMAT',
#  'https://finance.yahoo.com/quote/APTV?p=APTV',
#  'https://finance.yahoo.com/quote/ACGL?p=ACGL',
#  'https://finance.yahoo.com/quote/ANET?p=ANET',
#  'https://finance.yahoo.com/quote/AJG?p=AJG',
#  'https://finance.yahoo.com/quote/AIZ?p=AIZ',
#  'https://finance.yahoo.com/quote/T?p=T',
#  'https://finance.yahoo.com/quote/ATO?p=ATO',
#  'https://finance.yahoo.com/quote/ADSK?p=ADSK',
#  'https://finance.yahoo.com/quote/AZO?p=AZO',
#  'https://finance.yahoo.com/quote/AVB?p=AVB',
#  'https://finance.yahoo.com/quote/AVY?p=AVY',
#  'https://finance.yahoo.com/quote/AXON?p=AXON',
#  'https://finance.yahoo.com/quote/BKR?p=BKR',
#  'https://finance.yahoo.com/quote/BALL?p=BALL',
#  'https://finance.yahoo.com/quote/BAC?p=BAC',
#  'https://finance.yahoo.com/quote/BBWI?p=BBWI',
#  'https://finance.yahoo.com/quote/BAX?p=BAX',
#  'https://finance.yahoo.com/quote/BDX?p=BDX',
#  'https://finance.yahoo.com/quote/WRB?p=WRB',
#  'https://finance.yahoo.com/quote/BRK.B?p=BRK.B',
#  'https://finance.yahoo.com/quote/BBY?p=BBY',
#  'https://finance.yahoo.com/quote/BIO?p=BIO',
#  'https://finance.yahoo.com/quote/TECH?p=TECH',
#  'https://finance.yahoo.com/quote/BIIB?p=BIIB',
#  'https://finance.yahoo.com/quote/BLK?p=BLK',
#  'https://finance.yahoo.com/quote/BK?p=BK',
#  'https://finance.yahoo.com/quote/BA?p=BA',
#  'https://finance.yahoo.com/quote/BKNG?p=BKNG',
#  'https://finance.yahoo.com/quote/BWA?p=BWA',
#  'https://finance.yahoo.com/quote/BXP?p=BXP',
#  'https://finance.yahoo.com/quote/BSX?p=BSX',
#  'https://finance.yahoo.com/quote/BMY?p=BMY',
#  'https://finance.yahoo.com/quote/AVGO?p=AVGO',
#  'https://finance.yahoo.com/quote/BR?p=BR',
#  'https://finance.yahoo.com/quote/BRO?p=BRO',
#  'https://finance.yahoo.com/quote/BF.B?p=BF.B',
#  'https://finance.yahoo.com/quote/BG?p=BG',
#  'https://finance.yahoo.com/quote/CHRW?p=CHRW',
#  'https://finance.yahoo.com/quote/CDNS?p=CDNS',
#  'https://finance.yahoo.com/quote/CZR?p=CZR',
#  'https://finance.yahoo.com/quote/CPT?p=CPT',
#  'https://finance.yahoo.com/quote/CPB?p=CPB',
#  'https://finance.yahoo.com/quote/COF?p=COF',
#  'https://finance.yahoo.com/quote/CAH?p=CAH',
#  'https://finance.yahoo.com/quote/KMX?p=KMX',
#  'https://finance.yahoo.com/quote/CCL?p=CCL',
#  'https://finance.yahoo.com/quote/CARR?p=CARR',
#  'https://finance.yahoo.com/quote/CTLT?p=CTLT',
#  'https://finance.yahoo.com/quote/CAT?p=CAT',
#  'https://finance.yahoo.com/quote/CBOE?p=CBOE',
#  'https://finance.yahoo.com/quote/CBRE?p=CBRE',
#  'https://finance.yahoo.com/quote/CDW?p=CDW',
#  'https://finance.yahoo.com/quote/CE?p=CE',
#  'https://finance.yahoo.com/quote/CNC?p=CNC',
#  'https://finance.yahoo.com/quote/CNP?p=CNP',
#  'https://finance.yahoo.com/quote/CDAY?p=CDAY',
#  'https://finance.yahoo.com/quote/CF?p=CF',
#  'https://finance.yahoo.com/quote/CRL?p=CRL',
#  'https://finance.yahoo.com/quote/SCHW?p=SCHW',
#  'https://finance.yahoo.com/quote/CHTR?p=CHTR',
#  'https://finance.yahoo.com/quote/CVX?p=CVX',
#  'https://finance.yahoo.com/quote/CMG?p=CMG',
#  'https://finance.yahoo.com/quote/CB?p=CB',
#  'https://finance.yahoo.com/quote/CHD?p=CHD',
#  'https://finance.yahoo.com/quote/CI?p=CI',
#  'https://finance.yahoo.com/quote/CINF?p=CINF',
#  'https://finance.yahoo.com/quote/CTAS?p=CTAS',
#  'https://finance.yahoo.com/quote/CSCO?p=CSCO',
#  'https://finance.yahoo.com/quote/C?p=C',
#  'https://finance.yahoo.com/quote/CFG?p=CFG',
#  'https://finance.yahoo.com/quote/CLX?p=CLX',
#  'https://finance.yahoo.com/quote/CME?p=CME',
#  'https://finance.yahoo.com/quote/CMS?p=CMS',
#  'https://finance.yahoo.com/quote/KO?p=KO',
#  'https://finance.yahoo.com/quote/CTSH?p=CTSH',
#  'https://finance.yahoo.com/quote/CL?p=CL',
#  'https://finance.yahoo.com/quote/CMCSA?p=CMCSA',
#  'https://finance.yahoo.com/quote/CMA?p=CMA',
#  'https://finance.yahoo.com/quote/CAG?p=CAG',
#  'https://finance.yahoo.com/quote/COP?p=COP',
#  'https://finance.yahoo.com/quote/ED?p=ED',
#  'https://finance.yahoo.com/quote/STZ?p=STZ',
#  'https://finance.yahoo.com/quote/CEG?p=CEG',
#  'https://finance.yahoo.com/quote/COO?p=COO',
#  'https://finance.yahoo.com/quote/CPRT?p=CPRT',
#  'https://finance.yahoo.com/quote/GLW?p=GLW',
#  'https://finance.yahoo.com/quote/CTVA?p=CTVA',
#  'https://finance.yahoo.com/quote/CSGP?p=CSGP',
#  'https://finance.yahoo.com/quote/COST?p=COST',
#  'https://finance.yahoo.com/quote/CTRA?p=CTRA',
#  'https://finance.yahoo.com/quote/CCI?p=CCI',
#  'https://finance.yahoo.com/quote/CSX?p=CSX',
#  'https://finance.yahoo.com/quote/CMI?p=CMI',
#  'https://finance.yahoo.com/quote/CVS?p=CVS',
#  'https://finance.yahoo.com/quote/DHI?p=DHI',
#  'https://finance.yahoo.com/quote/DHR?p=DHR',
#  'https://finance.yahoo.com/quote/DRI?p=DRI',
#  'https://finance.yahoo.com/quote/DVA?p=DVA',
#  'https://finance.yahoo.com/quote/DE?p=DE',
#  'https://finance.yahoo.com/quote/DAL?p=DAL',
#  'https://finance.yahoo.com/quote/XRAY?p=XRAY',
#  'https://finance.yahoo.com/quote/DVN?p=DVN',
#  'https://finance.yahoo.com/quote/DXCM?p=DXCM',
#  'https://finance.yahoo.com/quote/FANG?p=FANG',
#  'https://finance.yahoo.com/quote/DLR?p=DLR',
#  'https://finance.yahoo.com/quote/DFS?p=DFS',
#  'https://finance.yahoo.com/quote/DISH?p=DISH',
#  'https://finance.yahoo.com/quote/DIS?p=DIS',
#  'https://finance.yahoo.com/quote/DG?p=DG',
#  'https://finance.yahoo.com/quote/DLTR?p=DLTR',
#  'https://finance.yahoo.com/quote/D?p=D',
#  'https://finance.yahoo.com/quote/DPZ?p=DPZ',
#  'https://finance.yahoo.com/quote/DOV?p=DOV',
#  'https://finance.yahoo.com/quote/DOW?p=DOW',
#  'https://finance.yahoo.com/quote/DTE?p=DTE',
#  'https://finance.yahoo.com/quote/DUK?p=DUK',
#  'https://finance.yahoo.com/quote/DD?p=DD',
#  'https://finance.yahoo.com/quote/DXC?p=DXC',
#  'https://finance.yahoo.com/quote/EMN?p=EMN',
#  'https://finance.yahoo.com/quote/ETN?p=ETN',
#  'https://finance.yahoo.com/quote/EBAY?p=EBAY',
#  'https://finance.yahoo.com/quote/ECL?p=ECL',
#  'https://finance.yahoo.com/quote/EIX?p=EIX',
#  'https://finance.yahoo.com/quote/EW?p=EW',
#  'https://finance.yahoo.com/quote/EA?p=EA',
#  'https://finance.yahoo.com/quote/ELV?p=ELV',
#  'https://finance.yahoo.com/quote/LLY?p=LLY',
#  'https://finance.yahoo.com/quote/EMR?p=EMR',
#  'https://finance.yahoo.com/quote/ENPH?p=ENPH',
#  'https://finance.yahoo.com/quote/ETR?p=ETR',
#  'https://finance.yahoo.com/quote/EOG?p=EOG',
#  'https://finance.yahoo.com/quote/EPAM?p=EPAM',
#  'https://finance.yahoo.com/quote/EQT?p=EQT',
#  'https://finance.yahoo.com/quote/EFX?p=EFX',
#  'https://finance.yahoo.com/quote/EQIX?p=EQIX',
#  'https://finance.yahoo.com/quote/EQR?p=EQR',
#  'https://finance.yahoo.com/quote/ESS?p=ESS',
#  'https://finance.yahoo.com/quote/EL?p=EL',
#  'https://finance.yahoo.com/quote/ETSY?p=ETSY',
#  'https://finance.yahoo.com/quote/RE?p=RE',
#  'https://finance.yahoo.com/quote/EVRG?p=EVRG',
#  'https://finance.yahoo.com/quote/ES?p=ES',
#  'https://finance.yahoo.com/quote/EXC?p=EXC',
#  'https://finance.yahoo.com/quote/EXPE?p=EXPE',
#  'https://finance.yahoo.com/quote/EXPD?p=EXPD',
#  'https://finance.yahoo.com/quote/EXR?p=EXR',
#  'https://finance.yahoo.com/quote/XOM?p=XOM',
#  'https://finance.yahoo.com/quote/FFIV?p=FFIV',
#  'https://finance.yahoo.com/quote/FDS?p=FDS',
#  'https://finance.yahoo.com/quote/FICO?p=FICO',
#  'https://finance.yahoo.com/quote/FAST?p=FAST',
#  'https://finance.yahoo.com/quote/FRT?p=FRT',
#  'https://finance.yahoo.com/quote/FDX?p=FDX',
#  'https://finance.yahoo.com/quote/FITB?p=FITB',
#  'https://finance.yahoo.com/quote/FSLR?p=FSLR',
#  'https://finance.yahoo.com/quote/FE?p=FE',
#  'https://finance.yahoo.com/quote/FIS?p=FIS',
#  'https://finance.yahoo.com/quote/FISV?p=FISV',
#  'https://finance.yahoo.com/quote/FLT?p=FLT',
#  'https://finance.yahoo.com/quote/FMC?p=FMC',
#  'https://finance.yahoo.com/quote/F?p=F',
#  'https://finance.yahoo.com/quote/FTNT?p=FTNT',
#  'https://finance.yahoo.com/quote/FTV?p=FTV',
#  'https://finance.yahoo.com/quote/FOXA?p=FOXA',
#  'https://finance.yahoo.com/quote/FOX?p=FOX',
#  'https://finance.yahoo.com/quote/BEN?p=BEN',
#  'https://finance.yahoo.com/quote/FCX?p=FCX',
#  'https://finance.yahoo.com/quote/GRMN?p=GRMN',
#  'https://finance.yahoo.com/quote/IT?p=IT',
#  'https://finance.yahoo.com/quote/GEHC?p=GEHC',
#  'https://finance.yahoo.com/quote/GEN?p=GEN',
#  'https://finance.yahoo.com/quote/GNRC?p=GNRC',
#  'https://finance.yahoo.com/quote/GD?p=GD',
#  'https://finance.yahoo.com/quote/GE?p=GE',
#  'https://finance.yahoo.com/quote/GIS?p=GIS',
#  'https://finance.yahoo.com/quote/GM?p=GM',
#  'https://finance.yahoo.com/quote/GPC?p=GPC',
#  'https://finance.yahoo.com/quote/GILD?p=GILD',
#  'https://finance.yahoo.com/quote/GL?p=GL',
#  'https://finance.yahoo.com/quote/GPN?p=GPN',
#  'https://finance.yahoo.com/quote/GS?p=GS',
#  'https://finance.yahoo.com/quote/HAL?p=HAL',
#  'https://finance.yahoo.com/quote/HIG?p=HIG',
#  'https://finance.yahoo.com/quote/HAS?p=HAS',
#  'https://finance.yahoo.com/quote/HCA?p=HCA',
#  'https://finance.yahoo.com/quote/PEAK?p=PEAK',
#  'https://finance.yahoo.com/quote/HSIC?p=HSIC',
#  'https://finance.yahoo.com/quote/HSY?p=HSY',
#  'https://finance.yahoo.com/quote/HES?p=HES',
#  'https://finance.yahoo.com/quote/HPE?p=HPE',
#  'https://finance.yahoo.com/quote/HLT?p=HLT',
#  'https://finance.yahoo.com/quote/HOLX?p=HOLX',
#  'https://finance.yahoo.com/quote/HD?p=HD',
#  'https://finance.yahoo.com/quote/HON?p=HON',
#  'https://finance.yahoo.com/quote/HRL?p=HRL',
#  'https://finance.yahoo.com/quote/HST?p=HST',
#  'https://finance.yahoo.com/quote/HWM?p=HWM',
#  'https://finance.yahoo.com/quote/HPQ?p=HPQ',
#  'https://finance.yahoo.com/quote/HUM?p=HUM',
#  'https://finance.yahoo.com/quote/HBAN?p=HBAN',
#  'https://finance.yahoo.com/quote/HII?p=HII',
#  'https://finance.yahoo.com/quote/IBM?p=IBM',
#  'https://finance.yahoo.com/quote/IEX?p=IEX',
#  'https://finance.yahoo.com/quote/IDXX?p=IDXX',
#  'https://finance.yahoo.com/quote/ITW?p=ITW',
#  'https://finance.yahoo.com/quote/ILMN?p=ILMN',
#  'https://finance.yahoo.com/quote/INCY?p=INCY',
#  'https://finance.yahoo.com/quote/IR?p=IR',
#  'https://finance.yahoo.com/quote/PODD?p=PODD',
#  'https://finance.yahoo.com/quote/INTC?p=INTC',
#  'https://finance.yahoo.com/quote/ICE?p=ICE',
#  'https://finance.yahoo.com/quote/IFF?p=IFF',
#  'https://finance.yahoo.com/quote/IP?p=IP',
#  'https://finance.yahoo.com/quote/IPG?p=IPG',
#  'https://finance.yahoo.com/quote/INTU?p=INTU',
#  'https://finance.yahoo.com/quote/ISRG?p=ISRG',
#  'https://finance.yahoo.com/quote/IVZ?p=IVZ',
#  'https://finance.yahoo.com/quote/INVH?p=INVH',
#  'https://finance.yahoo.com/quote/IQV?p=IQV',
#  'https://finance.yahoo.com/quote/IRM?p=IRM',
#  'https://finance.yahoo.com/quote/JBHT?p=JBHT',
#  'https://finance.yahoo.com/quote/JKHY?p=JKHY',
#  'https://finance.yahoo.com/quote/J?p=J',
#  'https://finance.yahoo.com/quote/JNJ?p=JNJ',
#  'https://finance.yahoo.com/quote/JCI?p=JCI',
#  'https://finance.yahoo.com/quote/JPM?p=JPM',
#  'https://finance.yahoo.com/quote/JNPR?p=JNPR',
#  'https://finance.yahoo.com/quote/K?p=K',
#  'https://finance.yahoo.com/quote/KDP?p=KDP',
#  'https://finance.yahoo.com/quote/KEY?p=KEY',
#  'https://finance.yahoo.com/quote/KEYS?p=KEYS',
#  'https://finance.yahoo.com/quote/KMB?p=KMB',
#  'https://finance.yahoo.com/quote/KIM?p=KIM',
#  'https://finance.yahoo.com/quote/KMI?p=KMI',
#  'https://finance.yahoo.com/quote/KLAC?p=KLAC',
#  'https://finance.yahoo.com/quote/KHC?p=KHC',
#  'https://finance.yahoo.com/quote/KR?p=KR',
#  'https://finance.yahoo.com/quote/LHX?p=LHX',
#  'https://finance.yahoo.com/quote/LH?p=LH',
#  'https://finance.yahoo.com/quote/LRCX?p=LRCX',
#  'https://finance.yahoo.com/quote/LW?p=LW',
#  'https://finance.yahoo.com/quote/LVS?p=LVS',
#  'https://finance.yahoo.com/quote/LDOS?p=LDOS',
#  'https://finance.yahoo.com/quote/LEN?p=LEN',
#  'https://finance.yahoo.com/quote/LNC?p=LNC',
#  'https://finance.yahoo.com/quote/LIN?p=LIN',
#  'https://finance.yahoo.com/quote/LYV?p=LYV',
#  'https://finance.yahoo.com/quote/LKQ?p=LKQ',
#  'https://finance.yahoo.com/quote/LMT?p=LMT',
#  'https://finance.yahoo.com/quote/L?p=L',
#  'https://finance.yahoo.com/quote/LOW?p=LOW',
#  'https://finance.yahoo.com/quote/LYB?p=LYB',
#  'https://finance.yahoo.com/quote/MTB?p=MTB',
#  'https://finance.yahoo.com/quote/MRO?p=MRO',
#  'https://finance.yahoo.com/quote/MPC?p=MPC',
#  'https://finance.yahoo.com/quote/MKTX?p=MKTX',
#  'https://finance.yahoo.com/quote/MAR?p=MAR',
#  'https://finance.yahoo.com/quote/MMC?p=MMC',
#  'https://finance.yahoo.com/quote/MLM?p=MLM',
#  'https://finance.yahoo.com/quote/MAS?p=MAS',
#  'https://finance.yahoo.com/quote/MA?p=MA',
#  'https://finance.yahoo.com/quote/MTCH?p=MTCH',
#  'https://finance.yahoo.com/quote/MKC?p=MKC',
#  'https://finance.yahoo.com/quote/MCD?p=MCD',
#  'https://finance.yahoo.com/quote/MCK?p=MCK',
#  'https://finance.yahoo.com/quote/MDT?p=MDT',
#  'https://finance.yahoo.com/quote/MRK?p=MRK',
#  'https://finance.yahoo.com/quote/META?p=META',
#  'https://finance.yahoo.com/quote/MET?p=MET',
#  'https://finance.yahoo.com/quote/MTD?p=MTD',
#  'https://finance.yahoo.com/quote/MGM?p=MGM',
#  'https://finance.yahoo.com/quote/MCHP?p=MCHP',
#  'https://finance.yahoo.com/quote/MU?p=MU',
#  'https://finance.yahoo.com/quote/MSFT?p=MSFT',
#  'https://finance.yahoo.com/quote/MAA?p=MAA',
#  'https://finance.yahoo.com/quote/MRNA?p=MRNA',
#  'https://finance.yahoo.com/quote/MHK?p=MHK',
#  'https://finance.yahoo.com/quote/MOH?p=MOH',
#  'https://finance.yahoo.com/quote/TAP?p=TAP',
#  'https://finance.yahoo.com/quote/MDLZ?p=MDLZ',
#  'https://finance.yahoo.com/quote/MPWR?p=MPWR',
#  'https://finance.yahoo.com/quote/MNST?p=MNST',
#  'https://finance.yahoo.com/quote/MCO?p=MCO',
#  'https://finance.yahoo.com/quote/MS?p=MS',
#  'https://finance.yahoo.com/quote/MOS?p=MOS',
#  'https://finance.yahoo.com/quote/MSI?p=MSI',
#  'https://finance.yahoo.com/quote/MSCI?p=MSCI',
#  'https://finance.yahoo.com/quote/NDAQ?p=NDAQ',
#  'https://finance.yahoo.com/quote/NTAP?p=NTAP',
#  'https://finance.yahoo.com/quote/NFLX?p=NFLX',
#  'https://finance.yahoo.com/quote/NWL?p=NWL',
#  'https://finance.yahoo.com/quote/NEM?p=NEM',
#  'https://finance.yahoo.com/quote/NWSA?p=NWSA',
#  'https://finance.yahoo.com/quote/NWS?p=NWS',
#  'https://finance.yahoo.com/quote/NEE?p=NEE',
#  'https://finance.yahoo.com/quote/NKE?p=NKE',
#  'https://finance.yahoo.com/quote/NI?p=NI',
#  'https://finance.yahoo.com/quote/NDSN?p=NDSN',
#  'https://finance.yahoo.com/quote/NSC?p=NSC',
#  'https://finance.yahoo.com/quote/NTRS?p=NTRS',
#  'https://finance.yahoo.com/quote/NOC?p=NOC',
#  'https://finance.yahoo.com/quote/NCLH?p=NCLH',
#  'https://finance.yahoo.com/quote/NRG?p=NRG',
#  'https://finance.yahoo.com/quote/NUE?p=NUE',
#  'https://finance.yahoo.com/quote/NVDA?p=NVDA',
#  'https://finance.yahoo.com/quote/NVR?p=NVR',
#  'https://finance.yahoo.com/quote/NXPI?p=NXPI',
#  'https://finance.yahoo.com/quote/ORLY?p=ORLY',
#  'https://finance.yahoo.com/quote/OXY?p=OXY',
#  'https://finance.yahoo.com/quote/ODFL?p=ODFL',
#  'https://finance.yahoo.com/quote/OMC?p=OMC',
#  'https://finance.yahoo.com/quote/ON?p=ON',
#  'https://finance.yahoo.com/quote/OKE?p=OKE',
#  'https://finance.yahoo.com/quote/ORCL?p=ORCL',
#  'https://finance.yahoo.com/quote/OGN?p=OGN',
#  'https://finance.yahoo.com/quote/OTIS?p=OTIS',
#  'https://finance.yahoo.com/quote/PCAR?p=PCAR',
#  'https://finance.yahoo.com/quote/PKG?p=PKG',
#  'https://finance.yahoo.com/quote/PARA?p=PARA',
#  'https://finance.yahoo.com/quote/PH?p=PH',
#  'https://finance.yahoo.com/quote/PAYX?p=PAYX',
#  'https://finance.yahoo.com/quote/PAYC?p=PAYC',
#  'https://finance.yahoo.com/quote/PYPL?p=PYPL',
#  'https://finance.yahoo.com/quote/PNR?p=PNR',
#  'https://finance.yahoo.com/quote/PEP?p=PEP',
#  'https://finance.yahoo.com/quote/PKI?p=PKI',
#  'https://finance.yahoo.com/quote/PFE?p=PFE',
#  'https://finance.yahoo.com/quote/PCG?p=PCG',
#  'https://finance.yahoo.com/quote/PM?p=PM',
#  'https://finance.yahoo.com/quote/PSX?p=PSX',
#  'https://finance.yahoo.com/quote/PNW?p=PNW',
#  'https://finance.yahoo.com/quote/PXD?p=PXD',
#  'https://finance.yahoo.com/quote/PNC?p=PNC',
#  'https://finance.yahoo.com/quote/POOL?p=POOL',
#  'https://finance.yahoo.com/quote/PPG?p=PPG',
#  'https://finance.yahoo.com/quote/PPL?p=PPL',
#  'https://finance.yahoo.com/quote/PFG?p=PFG',
#  'https://finance.yahoo.com/quote/PG?p=PG',
#  'https://finance.yahoo.com/quote/PGR?p=PGR',
#  'https://finance.yahoo.com/quote/PLD?p=PLD',
#  'https://finance.yahoo.com/quote/PRU?p=PRU',
#  'https://finance.yahoo.com/quote/PEG?p=PEG',
#  'https://finance.yahoo.com/quote/PTC?p=PTC',
#  'https://finance.yahoo.com/quote/PSA?p=PSA',
#  'https://finance.yahoo.com/quote/PHM?p=PHM',
#  'https://finance.yahoo.com/quote/QRVO?p=QRVO',
#  'https://finance.yahoo.com/quote/PWR?p=PWR',
#  'https://finance.yahoo.com/quote/QCOM?p=QCOM',
#  'https://finance.yahoo.com/quote/DGX?p=DGX',
#  'https://finance.yahoo.com/quote/RL?p=RL',
#  'https://finance.yahoo.com/quote/RJF?p=RJF',
#  'https://finance.yahoo.com/quote/RTX?p=RTX',
#  'https://finance.yahoo.com/quote/O?p=O',
#  'https://finance.yahoo.com/quote/REG?p=REG',
#  'https://finance.yahoo.com/quote/REGN?p=REGN',
#  'https://finance.yahoo.com/quote/RF?p=RF',
#  'https://finance.yahoo.com/quote/RSG?p=RSG',
#  'https://finance.yahoo.com/quote/RMD?p=RMD',
#  'https://finance.yahoo.com/quote/RHI?p=RHI',
#  'https://finance.yahoo.com/quote/ROK?p=ROK',
#  'https://finance.yahoo.com/quote/ROL?p=ROL',
#  'https://finance.yahoo.com/quote/ROP?p=ROP',
#  'https://finance.yahoo.com/quote/ROST?p=ROST',
#  'https://finance.yahoo.com/quote/RCL?p=RCL',
#  'https://finance.yahoo.com/quote/SPGI?p=SPGI',
#  'https://finance.yahoo.com/quote/CRM?p=CRM',
#  'https://finance.yahoo.com/quote/SBAC?p=SBAC',
#  'https://finance.yahoo.com/quote/SLB?p=SLB',
#  'https://finance.yahoo.com/quote/STX?p=STX',
#  'https://finance.yahoo.com/quote/SEE?p=SEE',
#  'https://finance.yahoo.com/quote/SRE?p=SRE',
#  'https://finance.yahoo.com/quote/NOW?p=NOW',
#  'https://finance.yahoo.com/quote/SHW?p=SHW',
#  'https://finance.yahoo.com/quote/SPG?p=SPG',
#  'https://finance.yahoo.com/quote/SWKS?p=SWKS',
#  'https://finance.yahoo.com/quote/SJM?p=SJM',
#  'https://finance.yahoo.com/quote/SNA?p=SNA',
#  'https://finance.yahoo.com/quote/SEDG?p=SEDG',
#  'https://finance.yahoo.com/quote/SO?p=SO',
#  'https://finance.yahoo.com/quote/LUV?p=LUV',
#  'https://finance.yahoo.com/quote/SWK?p=SWK',
#  'https://finance.yahoo.com/quote/SBUX?p=SBUX',
#  'https://finance.yahoo.com/quote/STT?p=STT',
#  'https://finance.yahoo.com/quote/STLD?p=STLD',
#  'https://finance.yahoo.com/quote/STE?p=STE',
#  'https://finance.yahoo.com/quote/SYK?p=SYK',
#  'https://finance.yahoo.com/quote/SYF?p=SYF',
#  'https://finance.yahoo.com/quote/SNPS?p=SNPS',
#  'https://finance.yahoo.com/quote/SYY?p=SYY',
#  'https://finance.yahoo.com/quote/TMUS?p=TMUS',
#  'https://finance.yahoo.com/quote/TROW?p=TROW',
#  'https://finance.yahoo.com/quote/TTWO?p=TTWO',
#  'https://finance.yahoo.com/quote/TPR?p=TPR',
#  'https://finance.yahoo.com/quote/TRGP?p=TRGP',
#  'https://finance.yahoo.com/quote/TGT?p=TGT',
#  'https://finance.yahoo.com/quote/TEL?p=TEL',
#  'https://finance.yahoo.com/quote/TDY?p=TDY',
#  'https://finance.yahoo.com/quote/TFX?p=TFX',
#  'https://finance.yahoo.com/quote/TER?p=TER',
#  'https://finance.yahoo.com/quote/TSLA?p=TSLA',
#  'https://finance.yahoo.com/quote/TXN?p=TXN',
#  'https://finance.yahoo.com/quote/TXT?p=TXT',
#  'https://finance.yahoo.com/quote/TMO?p=TMO',
#  'https://finance.yahoo.com/quote/TJX?p=TJX',
#  'https://finance.yahoo.com/quote/TSCO?p=TSCO',
#  'https://finance.yahoo.com/quote/TT?p=TT',
#  'https://finance.yahoo.com/quote/TDG?p=TDG',
#  'https://finance.yahoo.com/quote/TRV?p=TRV',
#  'https://finance.yahoo.com/quote/TRMB?p=TRMB',
#  'https://finance.yahoo.com/quote/TFC?p=TFC',
#  'https://finance.yahoo.com/quote/TYL?p=TYL',
#  'https://finance.yahoo.com/quote/TSN?p=TSN',
#  'https://finance.yahoo.com/quote/USB?p=USB',
#  'https://finance.yahoo.com/quote/UDR?p=UDR',
#  'https://finance.yahoo.com/quote/ULTA?p=ULTA',
#  'https://finance.yahoo.com/quote/UNP?p=UNP',
#  'https://finance.yahoo.com/quote/UAL?p=UAL',
#  'https://finance.yahoo.com/quote/UPS?p=UPS',
#  'https://finance.yahoo.com/quote/URI?p=URI',
#  'https://finance.yahoo.com/quote/UNH?p=UNH',
#  'https://finance.yahoo.com/quote/UHS?p=UHS',
#  'https://finance.yahoo.com/quote/VLO?p=VLO',
#  'https://finance.yahoo.com/quote/VTR?p=VTR',
#  'https://finance.yahoo.com/quote/VRSN?p=VRSN',
#  'https://finance.yahoo.com/quote/VRSK?p=VRSK',
#  'https://finance.yahoo.com/quote/VZ?p=VZ',
#  'https://finance.yahoo.com/quote/VRTX?p=VRTX',
#  'https://finance.yahoo.com/quote/VFC?p=VFC',
#  'https://finance.yahoo.com/quote/VTRS?p=VTRS',
#  'https://finance.yahoo.com/quote/VICI?p=VICI',
#  'https://finance.yahoo.com/quote/V?p=V',
#  'https://finance.yahoo.com/quote/VMC?p=VMC',
#  'https://finance.yahoo.com/quote/WAB?p=WAB',
#  'https://finance.yahoo.com/quote/WBA?p=WBA',
#  'https://finance.yahoo.com/quote/WMT?p=WMT',
#  'https://finance.yahoo.com/quote/WBD?p=WBD',
#  'https://finance.yahoo.com/quote/WM?p=WM',
#  'https://finance.yahoo.com/quote/WAT?p=WAT',
#  'https://finance.yahoo.com/quote/WEC?p=WEC',
#  'https://finance.yahoo.com/quote/WFC?p=WFC',
#  'https://finance.yahoo.com/quote/WELL?p=WELL',
#  'https://finance.yahoo.com/quote/WST?p=WST',
#  'https://finance.yahoo.com/quote/WDC?p=WDC',
#  'https://finance.yahoo.com/quote/WRK?p=WRK',
#  'https://finance.yahoo.com/quote/WY?p=WY',
#  'https://finance.yahoo.com/quote/WHR?p=WHR',
#  'https://finance.yahoo.com/quote/WMB?p=WMB',
#  'https://finance.yahoo.com/quote/WTW?p=WTW',
#  'https://finance.yahoo.com/quote/GWW?p=GWW',
#  'https://finance.yahoo.com/quote/WYNN?p=WYNN',
#  'https://finance.yahoo.com/quote/XEL?p=XEL',
#  'https://finance.yahoo.com/quote/XYL?p=XYL',
#  'https://finance.yahoo.com/quote/YUM?p=YUM',
#  'https://finance.yahoo.com/quote/ZBRA?p=ZBRA',
#  'https://finance.yahoo.com/quote/ZBH?p=ZBH',
#  'https://finance.yahoo.com/quote/ZION?p=ZION',
#  'https://finance.yahoo.com/quote/ZTS?p=ZTS']
